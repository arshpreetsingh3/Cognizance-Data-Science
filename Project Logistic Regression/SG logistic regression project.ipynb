# %%
import pandas as pd 
import numpy as np

x = pd.read_csv("0000000000002429_training_titanic_x_y_train.csv")
test = pd.read_csv("0000000000002429_test_titanic_x_test.csv")

y = x.copy()

x2 = x[x.Survived == 1]
survive_age = x2.Age.mean()
x2 = x[x.Survived == 0]
not_survive_age = x2.Age.mean()
print(survive_age)
print(not_survive_age)
r,c = y.shape
z = y[y.Age.isnull()]

k = z.index.values

for i in range(r):
    if i in k:
        if(y.loc[i,'Survived']==1):
            y.loc[i,"Age"]=survive_age
        else:
            y.loc[i,"Age"]=not_survive_age
#y.Age.fillna(test.Age.mean(),inplace = True)
del y['Name']
del y['Survived']
del y['Fare']
test.Age.fillna(test.Age.mean(),inplace = True)
#y['age_age'] = y['Age']**2
#test['age_age'] = test['Age']**2


def f1(s):
    if s == 'male':
        return 0
    else:
        return 1
def getNumberEmbarked(str):
    if str=='C':
        return 1
    elif str=='Q':
        return 2
    else:
        return 3
y['Embarked'] = y['Embarked'].apply(getNumberEmbarked)   
test['Embarked'] = test['Embarked'].apply(getNumberEmbarked)
    
y['Gender'] = y.Sex.apply(f1)

del y['Sex']
#del y['Embarked']
#del test['Embarked']
del y['Ticket']
del y['Parch']
y['Cabin'] = y.Cabin.notnull().astype(int)

test['Gender'] = test.Sex.apply(f1)
del test['Sex']

del test['Name']
test['Cabin'] = test.Cabin.notnull().astype(int)
del test["Fare"]
del test['Ticket']
del test['Parch']
#del y['Cabin']
#del test['Cabin']

from sklearn.linear_model import LogisticRegression

#clf = LogisticRegression()
#from sklearn import preprocessing
#Scaler = preprocessing.StandardScaler()
#Scaler.fit(y)
#i = Scaler.transform(y)
#j = Scaler.transform(test)
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth = 6, random_state=0)
clf.fit(y, x.Survived)
Y_pred = clf.predict(test)
np.savetxt('large.csv',Y_pred)
#clf.score(X_train_l,Y_train_l)

#print(y)
#print(test)
#clf.fit(y,x.Survived)
#y_pred = clf.predict(y)
#pred = clf.predict(test)
#np.savetxt('large.csv',pred)
#print(clf.score(y,x.Survived))
#print(y)
#print(test)
#y[y.age_age.isna()]
#print(y_pred - x.Survived)
#print(clf.predict_proba(y))

printy
# Out:
# 28.138157894736842
# 30.857142857142858
#      Pclass        Age  SibSp  Cabin  Embarked  Gender
# 0         2  29.000000      1      0         3       1
