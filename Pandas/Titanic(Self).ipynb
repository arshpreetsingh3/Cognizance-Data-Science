# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("titanic_train.csv")

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Analyse which columns can be deleted

# %%
#passenger id  : can be deleted 
#pclass : may be can matter 
#name : can be deleted 
#sex: can matter 
#age: can matter
#sib sp : no idea
#parch: no idea
#ticket: can be deleted surely 
#fare : can be deleted surely 
#cabin : maybe can matter 
#embarked : maybe can matter

# %%
data.drop('Name',axis=1,inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# 5              6         0       3    male   NaN      0      0
# 6              7         0       1    male  54.0      0      0
# 7              8         0       3    male   2.0      3      1
# 8              9         1       3  female  27.0      0      2
# 9             10         1       2  female  14.0      1      0
# 10            11         1       3  female   4.0      1      1
# 11            12         1       1  female  58.0      0      0
# 12            13         0       3    male  20.0      0      0
# 13            14         0       3    male  39.0      1      5
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
data.drop("Ticket",axis=1,inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
data.drop("PassengerId",axis=1,inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
data.drop("Parch",axis=1,inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp     Fare Cabin Embarked
# 0         0       3    male  22.0      1   7.2500   NaN        S
# 1         1       1  female  38.0      1  71.2833   C85        C
# 2         1       3  female  26.0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1  53.1000  C123        S
# 4         0       3    male  35.0      0   8.0500   NaN        S

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-3d8483998d6f> in <module>()
# ----> 1 data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
data.shape
# Out:
# (891, 8)

# %%
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp      Fare        Cabin Embarked
# 0           0       3    male  22.0      1    7.2500          NaN        S
# 1           1       1  female  38.0      1   71.2833          C85        C
# 2           1       3  female  26.0      0    7.9250          NaN        S
# 3           1       1  female  35.0      1   53.1000         C123        S
# 4           0       3    male  35.0      0    8.0500          NaN        S
# 5           0       3    male   NaN      0    8.4583          NaN        Q
# 6           0       1    male  54.0      0   51.8625          E46        S
# 7           0       3    male   2.0      3   21.0750          NaN        S
# 8           1       3  female  27.0      0   11.1333          NaN        S
# 9           1       2  female  14.0      1   30.0708          NaN        C
# 10          1       3  female   4.0      1   16.7000           G6        S
# ...

# %%
data.shape
# Out:
# (891, 8)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp     Fare Cabin Embarked
# 0         0       3    male  22.0      1   7.2500   NaN        S
# 1         1       1  female  38.0      1  71.2833   C85        C
# 2         1       3  female  26.0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1  53.1000  C123        S
# 4         0       3    male  35.0      0   8.0500   NaN        S

# %%
del data["Cabin"]
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp     Fare Embarked
# 0         0       3    male  22.0      1   7.2500        S
# 1         1       1  female  38.0      1  71.2833        C
# 2         1       3  female  26.0      0   7.9250        S
# 3         1       1  female  35.0      1  53.1000        S
# 4         0       3    male  35.0      0   8.0500        S

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008   32.204208
# std      0.486592    0.836071   14.526497    1.102743   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000  512.329200

# %%
del data["Fare"]

# %%
data.shape
# Out:
# (891, 6)

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp
# count  891.000000  891.000000  714.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008
# std      0.486592    0.836071   14.526497    1.102743
# min      0.000000    1.000000    0.420000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000
# 50%      0.000000    3.000000   28.000000    0.000000
# 75%      1.000000    3.000000   38.000000    1.000000
# max      1.000000    3.000000   80.000000    8.000000

# %%
data.shape
# Out:
# (891, 6)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp Embarked
# 0         0       3    male  22.0      1        S
# 1         1       1  female  38.0      1        C
# 2         1       3  female  26.0      0        S
# 3         1       1  female  35.0      1        S
# 4         0       3    male  35.0      0        S

# %%
# Finding the number of people who have survived 
# given that they have embarked or boarded from a particular port

survivedfromQ = data[data.Embarked == 'Q'][data.Survived == 1].shape[0]
survivedfromQ
survivedfromC = data[data.Embarked == 'C'][data.Survived == 1].shape[0]
survivedfromC
survivedfromS = data[data.Embarked == 'S'][data.Survived == 1].shape[0]
survivedfromS
#similarly checked for C and S too and the results were
# Survived for C=93
# Survived for S=217
# Out:
# C:\Users\Arshpreet Singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# C:\Users\Arshpreet Singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\Arshpreet Singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 217

# %%
survivedfromC = data[data.Embarked == 'C'][data.Survived == 1].shape[0]
survivedfromC
# Out:
# C:\Users\Arshpreet Singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 93

# %%
survivedfromQ = data[data.Embarked == 'Q'][data.Survived == 1].shape[0]
survivedfromQ
# Out:
# C:\Users\Arshpreet Singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 30

# %%
notsurvivedfromQ= data[data.Embarked=="Q"][data.Survived==0].shape[0]
notsurvivedfromQ
# Out:
# C:\Users\Arshpreet Singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 47

# %%
notsurvivedfromS= data[data.Embarked=="S"][data.Survived==0].shape[0]
notsurvivedfromS
# Out:
# C:\Users\Arshpreet Singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 427

# %%
notsurvivedfromC= data[data.Embarked=="C"][data.Survived==0].shape[0]
notsurvivedfromC
# Out:
# C:\Users\Arshpreet Singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 75

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Embarked      2
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Embarked      2
# dtype: int64

# %%
def sex(s):
    if s=='male':
        return 0
    else:
        return 1

# %%
data["gender"]=data["Sex"].apply(sex)

# %%
data.head()
#for females the value in gender is 1 and for males the value is 0
# Out:
#    Survived  Pclass     Sex   Age  SibSp Embarked  gender
# 0         0       3    male  22.0      1        S       0
# 1         1       1  female  38.0      1        C       1
# 2         1       3  female  26.0      0        S       1
# 3         1       1  female  35.0      1        S       1
# 4         0       3    male  35.0      0        S       0

# %%
del data["Sex"]
data.head()
# Out:
#    Survived  Pclass   Age  SibSp Embarked  gender
# 0         0       3  22.0      1        S       0
# 1         1       1  38.0      1        C       1
# 2         1       3  26.0      0        S       1
# 3         1       1  35.0      1        S       1
# 4         0       3  35.0      0        S       0

# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
males = (data['gender'] == 0).sum() 
#Summing up all the values of column gender with a 
#condition for male and similary for females
females = (data['gender'] == 1).sum()
print(males)
print(females)
# Out:
# 577
# 314

# %%
p = [males, females]
plt.pie(p,    #giving array
       labels = ['Male', 'Female'], #Correspndingly giving labels
       colors = ['blue', 'red'],   # Corresponding colors
       explode = (0.15, 0),    #How much the gap should me there between the pies
       startangle = 0)  #what start angle should be given
plt.axis('equal') 
plt.show()

# %%
data.head()
# Out:
#    Survived  Pclass   Age  SibSp Embarked  gender
# 0         0       3  22.0      1        S       0
# 1         1       1  38.0      1        C       1
# 2         1       3  26.0      0        S       1
# 3         1       1  35.0      1        S       1
# 4         0       3  35.0      0        S       0

# %%
meanS= data[data.Survived==1].Age.mean()
meanS
# Out:
# 28.343689655172415

# %%
data["age"]=np.where(pd.isnull(data.Age) & data["Survived"]==1 ,meanS, data["Age"])
data
# Out:
#      Survived  Pclass   Age  SibSp Embarked  gender       age
# 0           0       3  22.0      1        S       0  22.00000
# 1           1       1  38.0      1        C       1  38.00000
# 2           1       3  26.0      0        S       1  26.00000
# 3           1       1  35.0      1        S       1  35.00000
# 4           0       3  35.0      0        S       0  35.00000
# 5           0       3   NaN      0        Q       0       NaN
# 6           0       1  54.0      0        S       0  54.00000
# 7           0       3   2.0      3        S       0   2.00000
# 8           1       3  27.0      0        S       1  27.00000
# 9           1       2  14.0      1        C       1  14.00000
# 10          1       3   4.0      1        S       1   4.00000
# 11          1       1  58.0      0        S       1  58.00000
# 12          0       3  20.0      0        S       0  20.00000
# 13          0       3  39.0      1        S       0  39.00000
# ...

# %%
# Finding the mean age of "Not Survived" people
meanNS=data[data.Survived==0].Age.mean()
meanNS
# Out:
# 30.62617924528302

# %%
data.age.fillna(meanNS,inplace=True)
data
# Out:
#      Survived  Pclass   Age  SibSp Embarked  gender        age
# 0           0       3  22.0      1        S       0  22.000000
# 1           1       1  38.0      1        C       1  38.000000
# 2           1       3  26.0      0        S       1  26.000000
# 3           1       1  35.0      1        S       1  35.000000
# 4           0       3  35.0      0        S       0  35.000000
# 5           0       3   NaN      0        Q       0  30.626179
# 6           0       1  54.0      0        S       0  54.000000
# 7           0       3   2.0      3        S       0   2.000000
# 8           1       3  27.0      0        S       1  27.000000
# 9           1       2  14.0      1        C       1  14.000000
# 10          1       3   4.0      1        S       1   4.000000
# 11          1       1  58.0      0        S       1  58.000000
# 12          0       3  20.0      0        S       0  20.000000
# 13          0       3  39.0      1        S       0  39.000000
# ...

# %%
del data["Age"]
data
# Out:
#      Survived  Pclass  SibSp Embarked  gender        age
# 0           0       3      1        S       0  22.000000
# 1           1       1      1        C       1  38.000000
# 2           1       3      0        S       1  26.000000
# 3           1       1      1        S       1  35.000000
# 4           0       3      0        S       0  35.000000
# 5           0       3      0        Q       0  30.626179
# 6           0       1      0        S       0  54.000000
# 7           0       3      3        S       0   2.000000
# 8           1       3      0        S       1  27.000000
# 9           1       2      1        C       1  14.000000
# 10          1       3      1        S       1   4.000000
# 11          1       1      0        S       1  58.000000
# 12          0       3      0        S       0  20.000000
# 13          0       3      1        S       0  39.000000
# 14          0       3      0        S       1  14.000000
# ...

# %%
#Renaming "age" and "gender" columns
data.rename(columns={'age':'Age'}, inplace=True)
data.rename(columns={'gender':'Sex'}, inplace=True)
data.head()
# Out:
#    Survived  Pclass  SibSp Embarked  Sex   Age
# 0         0       3      1        S    0  22.0
# 1         1       1      1        C    1  38.0
# 2         1       3      0        S    1  26.0
# 3         1       1      1        S    1  35.0
# 4         0       3      0        S    0  35.0

# %%
data.shape
# Out:
# (891, 6)

# %%
#### Now removing two rows where embarked value was null (Discussed in the beginning)
data.dropna(inplace=True)
data.head()
# Out:
#    Survived  Pclass  SibSp Embarked  Sex   Age
# 0         0       3      1        S    0  22.0
# 1         1       1      1        C    1  38.0
# 2         1       3      0        S    1  26.0
# 3         1       1      1        S    1  35.0
# 4         0       3      0        S    0  35.0

# %%
data.shape
# Out:
# (889, 6)
